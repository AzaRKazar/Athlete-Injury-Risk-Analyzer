# %%
import pandas as pd
import numpy as np

# %%
vald_data = pd.read_csv('data/pivot_vald_data.csv')

# %%
vald_data
# Out:
#            sbuid               testDateUtc  leftAvgForce  leftCalibration  \
# 0     14568521.0  2022-01-28T14:25:44.908Z    364.812500              0.0
# 1     14568521.0  2022-03-24T14:19:33.592Z    460.750000              0.0
# 2     14568521.0  2022-05-27T15:32:31.396Z    465.750000              0.0
# 3     14568521.0  2022-06-17T15:18:00.057Z    448.000000              0.0
# 4     14568521.0  2022-07-01T15:10:19.541Z    496.583333              0.0
# ..           ...                       ...           ...              ...
# 986  116196314.0  2024-03-19T12:18:57.508Z    426.000000              0.0
# 987  116196314.0  2024-06-06T12:19:27.454Z    414.750000              0.0
# 988  116196314.0  2024-07-03T13:11:17.939Z    396.250000              0.0
# 989  116196314.0  2024-07-12T12:11:58.068Z    387.250000              0.0
# 990  116196314.0  2024-07-26T11:49:47.405Z    391.500000              0.0
#
#      leftImpulse  leftMaxForce  leftRepetitions  leftTorque  rightAvgForce  \
# 0       6375.605        450.75              4.0  184.582125     347.937500
# 1       8661.625        473.00              3.0  193.693500     511.833333
# 2       8750.730        481.25              3.0  197.071875     491.583333
# 3       9147.955        462.50              3.0  189.393750     418.916667
# 4       9311.730        508.25              3.0  208.128375     478.000000
# ..           ...           ...              ...         ...            ...
# 986     4867.330        426.00              1.0  193.617000     515.500000
# 987     4018.515        414.75              1.0  188.503875     515.750000
# 988     4591.660        396.25              0.0  183.661875     512.750000
# 989     5937.870        387.25              1.0  179.490375     509.500000
# 990     6757.875        397.25              2.0  184.125375     492.750000
#
#      rightCalibration  rightImpulse  rightMaxForce  rightRepetitions  \
# 0                 0.0      6104.060         451.50               4.0
# 1                 0.0      8758.945         529.25               3.0
# 2                 0.0      8295.600         521.00               3.0
# 3                 0.0      8099.180         443.25               3.0
# 4                 0.0      7821.835         504.00               3.0
# ..                ...           ...            ...               ...
# 986               0.0      5686.100         515.50               1.0
# 987               0.0      4267.670         515.75               1.0
# 988               0.0      5257.880         512.75               0.0
# 989               0.0      6422.515         509.50               1.0
# 990               0.0      6776.045         510.75               2.0
#
#      rightTorque
# 0     184.889250
# 1     216.727875
# 2     213.349500
# 3     181.510875
# 4     206.388000
# ..           ...
# 986   234.294750
# 987   234.408375
# 988   237.659625
# 989   236.153250
# 990   236.732625
#
# [991 rows x 14 columns]

# %%
vald_data.drop(columns=['leftCalibration','rightCalibration','leftRepetitions','rightRepetitions'], inplace=True)

# %%
vald_data
# Out:
#            sbuid               testDateUtc  leftAvgForce  leftImpulse  \
# 0     14568521.0  2022-01-28T14:25:44.908Z    364.812500     6375.605
# 1     14568521.0  2022-03-24T14:19:33.592Z    460.750000     8661.625
# 2     14568521.0  2022-05-27T15:32:31.396Z    465.750000     8750.730
# 3     14568521.0  2022-06-17T15:18:00.057Z    448.000000     9147.955
# 4     14568521.0  2022-07-01T15:10:19.541Z    496.583333     9311.730
# ..           ...                       ...           ...          ...
# 986  116196314.0  2024-03-19T12:18:57.508Z    426.000000     4867.330
# 987  116196314.0  2024-06-06T12:19:27.454Z    414.750000     4018.515
# 988  116196314.0  2024-07-03T13:11:17.939Z    396.250000     4591.660
# 989  116196314.0  2024-07-12T12:11:58.068Z    387.250000     5937.870
# 990  116196314.0  2024-07-26T11:49:47.405Z    391.500000     6757.875
#
#      leftMaxForce  leftTorque  rightAvgForce  rightImpulse  rightMaxForce  \
# 0          450.75  184.582125     347.937500      6104.060         451.50
# 1          473.00  193.693500     511.833333      8758.945         529.25
# 2          481.25  197.071875     491.583333      8295.600         521.00
# 3          462.50  189.393750     418.916667      8099.180         443.25
# 4          508.25  208.128375     478.000000      7821.835         504.00
# ..            ...         ...            ...           ...            ...
# 986        426.00  193.617000     515.500000      5686.100         515.50
# 987        414.75  188.503875     515.750000      4267.670         515.75
# 988        396.25  183.661875     512.750000      5257.880         512.75
# 989        387.25  179.490375     509.500000      6422.515         509.50
# 990        397.25  184.125375     492.750000      6776.045         510.75
#
#      rightTorque
# 0     184.889250
# 1     216.727875
# 2     213.349500
# 3     181.510875
# 4     206.388000
# ..           ...
# 986   234.294750
# 987   234.408375
# 988   237.659625
# 989   236.153250
# 990   236.732625
#
# [991 rows x 10 columns]

# %%
data=vald_data
# Adding new columns for  each symmetry ratio
data['ForceSymmetry'] = data['leftAvgForce'] / data['rightAvgForce']
data['ImpulseSymmetry'] = data['leftImpulse'] / data['rightImpulse']
data['MaxForceSymmetry'] = data['leftMaxForce'] / data['rightMaxForce']
data['TorqueSymmetry'] = data['leftTorque'] / data['rightTorque']

# %%
data[["ForceSymmetry","ImpulseSymmetry","MaxForceSymmetry","TorqueSymmetry"]].describe()
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        ForceSymmetry  ImpulseSymmetry  MaxForceSymmetry  TorqueSymmetry
# count     990.000000       989.000000        990.000000      988.000000
# mean             inf         1.076168               inf             inf
# std              NaN         0.173415               NaN             NaN
# min         0.493329         0.283250          0.505004        0.505004
# 25%         0.969582         0.976469          0.971012        0.971298
# 50%         1.045625         1.054293          1.046160        1.046418
# 75%         1.122082         1.154068          1.126282        1.126563
# max              inf         2.305306               inf             inf

# %%
# Replace infinity values with NaN
data.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Remove duplicate rows
data.drop_duplicates(inplace=True)

# %%
# Remove rows where all relevant metrics are zero
metric_columns = ['leftAvgForce', 'leftImpulse', 'leftMaxForce', 'leftTorque', 
                  'rightAvgForce', 'rightImpulse', 'rightMaxForce', 'rightTorque']
data = data[~(data[metric_columns].eq(0).any(axis=1))]

# %%
# data_dupliate=data.copy()
data.describe()
# Out:
#               sbuid  leftAvgForce   leftImpulse  leftMaxForce  leftTorque  \
# count  9.870000e+02    987.000000    987.000000    987.000000  987.000000
# mean   1.124961e+08    447.897549   5501.560679    471.151216  211.599031
# std    1.548802e+07     98.168709   2609.308495     97.396952   50.686340
# min    1.456852e+07     39.000000     28.815000     39.000000   16.321500
# 25%    1.143308e+08    376.437500   3556.140000    399.375000  174.724312
# 50%    1.149838e+08    448.083333   5222.160000    473.000000  210.400875
# 75%    1.156988e+08    518.833333   7108.350000    541.125000  246.978000
# max    1.161963e+08    751.625000  16512.365000    774.500000  389.892375
#
#        rightAvgForce  rightImpulse  rightMaxForce  rightTorque  ForceSymmetry  \
# count     987.000000    987.000000     987.000000   987.000000     987.000000
# mean      427.775716   5212.248075     449.433891   201.790613       1.054893
# std        90.649796   2508.610345      89.501803    46.568454       0.142034
# min        72.250000     58.020000      72.250000    30.236625       0.493329
# 25%       362.395833   3357.367500     388.750000   170.033625       0.969600
# 50%       432.250000   4919.225000     456.500000   201.772125       1.045629
# 75%       492.875000   6786.175000     515.000000   234.680625       1.122069
# max       772.250000  15213.510000     772.250000   357.937875       2.078358
#
#        ImpulseSymmetry  MaxForceSymmetry  TorqueSymmetry
# count       987.000000        987.000000      987.000000
# mean          1.076269          1.056428        1.056428
# std           0.173572          0.142066        0.142066
# min           0.283250          0.505004        0.505004
# 25%           0.976363          0.971155        0.971155
# 50%           1.054293          1.046272        1.046272
# 75%           1.154078          1.126269        1.126269
# max           2.305306          2.078358        2.078358

# %%
symmetry_columns = ['ForceSymmetry', 'ImpulseSymmetry', 'MaxForceSymmetry', 'TorqueSymmetry']
# Step 4: Outlier Treatment
# Define a function to cap outliers based on the IQR method
def cap_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return series.clip(lower=lower_bound, upper=upper_bound)

# Apply the function to symmetry columns
for col in symmetry_columns:
    data[col] = cap_outliers(data[col])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_20616\805879736.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = cap_outliers(data[col])
# C:\Users\USER\AppData\Local\Temp\ipykernel_20616\805879736.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = cap_outliers(data[col])
# C:\Users\USER\AppData\Local\Temp\ipykernel_20616\805879736.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = cap_outliers(data[col])
# C:\Users\USER\AppData\Local\Temp\ipykernel_20616\805879736.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = cap_outliers(data[col])

# %%
data.describe()
# Out:
#               sbuid  leftAvgForce   leftImpulse  leftMaxForce  leftTorque  \
# count  9.870000e+02    987.000000    987.000000    987.000000  987.000000
# mean   1.124961e+08    447.897549   5501.560679    471.151216  211.599031
# std    1.548802e+07     98.168709   2609.308495     97.396952   50.686340
# min    1.456852e+07     39.000000     28.815000     39.000000   16.321500
# 25%    1.143308e+08    376.437500   3556.140000    399.375000  174.724312
# 50%    1.149838e+08    448.083333   5222.160000    473.000000  210.400875
# 75%    1.156988e+08    518.833333   7108.350000    541.125000  246.978000
# max    1.161963e+08    751.625000  16512.365000    774.500000  389.892375
#
#        rightAvgForce  rightImpulse  rightMaxForce  rightTorque  ForceSymmetry  \
# count     987.000000    987.000000     987.000000   987.000000     987.000000
# mean      427.775716   5212.248075     449.433891   201.790613       1.052344
# std        90.649796   2508.610345      89.501803    46.568454       0.125037
# min        72.250000     58.020000      72.250000    30.236625       0.740896
# 25%       362.395833   3357.367500     388.750000   170.033625       0.969600
# 50%       432.250000   4919.225000     456.500000   201.772125       1.045629
# 75%       492.875000   6786.175000     515.000000   234.680625       1.122069
# max       772.250000  15213.510000     772.250000   357.937875       1.350772
#
#        ImpulseSymmetry  MaxForceSymmetry  TorqueSymmetry
# count       987.000000        987.000000      987.000000
# mean          1.072752          1.053861        1.053861
# std           0.151197          0.125259        0.125259
# min           0.709789          0.738484        0.738484
# 25%           0.976363          0.971155        0.971155
# 50%           1.054293          1.046272        1.046272
# 75%           1.154078          1.126269        1.126269
# max           1.420651          1.358941        1.358941

# %%
data[symmetry_columns].describe()
# Out:
#        ForceSymmetry  ImpulseSymmetry  MaxForceSymmetry  TorqueSymmetry
# count     987.000000       987.000000        987.000000      987.000000
# mean        1.052344         1.072752          1.053861        1.053861
# std         0.125037         0.151197          0.125259        0.125259
# min         0.740896         0.709789          0.738484        0.738484
# 25%         0.969600         0.976363          0.971155        0.971155
# 50%         1.045629         1.054293          1.046272        1.046272
# 75%         1.122069         1.154078          1.126269        1.126269
# max         1.350772         1.420651          1.358941        1.358941

# %%
data["testDateUtc"] = pd.to_datetime(data["testDateUtc"]).dt.date
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_20616\4285988865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["testDateUtc"] = pd.to_datetime(data["testDateUtc"]).dt.date

# %%
data.to_csv('data/preprocessed_vald_data.csv', index=False)
